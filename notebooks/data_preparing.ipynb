# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_pickle('../data/winrate.pkl')

# %%
handcraft=pd.read_excel('handcraft.xlsx')

# %%
handcraft.set_index(0, inplace=True)

# %%
np.concatenate([handcraft.loc['아리'].values, handcraft.loc['아리'].values])
# Out:
# array([1, 0, 0, 1, 1, 0, 0, 1, 0, 0, 1, 1, 0, 0])

# %%
pick = []
for i in range(len(data)):
    pp = []
    for j in range(5):
        pp.append(handcraft.loc[data[i][j][1]])
    for j in range(5) :
        pp.append(handcraft.loc[data[i][10+j][1]])
    pp = list(np.concatenate(pp))
    pp.append(data[i][-1])
    pick.append(pp)

# %%
data
# Out:
# [[('duo_support', '소라카', 'silver two'),
#   ('mid_lane', '녹턴', 'silver three'),
#   ('jungle', '리 신', 'silver four'),
#   ('duo_carry', '베인', 'silver four'),
#   ('top_lane', '다리우스', 'silver one'),
#   '퀸',
#   '르블랑',
#   '이블린',
#   '레오나',
#   '모르가나',
#   ('jungle', '케인', 'silver three'),
#   ('mid_lane', '말파이트', 'silver three'),
#   ('top_lane', '나르', 'bronze one'),
#   ('solo', '카이사', 'silver four'),
#   ('top_lane', '우르곳', 'silver three'),
#   '니코',
#   '제이스',
#   '야스오',
#   '이렐리아',
#   '이즈리얼',
#   True],
#  [('duo_support', '갈리오', 'silver four'),
#   ('top_lane', '카밀', 'silver three'),
#   ('duo_carry', '베인', 'silver four'),
#   ('jungle', '케인', 'silver four'),
#   ('mid_lane', '피즈', 'silver three'),
#   '누누와 윌럼프',
#   '아칼리',
#   '티모',
#   '룰루',
#   '이렐리아',
#   ('duo_carry', '케이틀린', 'silver three'),
#   ('top_lane', '판테온', 'silver four'),
#   ('jungle', '잭스', 'silver four'),
#   ('duo_support', '피들스틱', 'silver two'),
#   ('mid_lane', '카사딘', 'silver two'),
#   '루시안',
#   '아칼리',
# ...

# %%
df = pd.DataFrame(pick)

# %%
import pickle as pkl
