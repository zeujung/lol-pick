# %%
import pickle

# %%
with open('../data/3490000000-3492500000/7.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# [[('top_lane', '카르마', 'gold two'),
#   ('mid_lane', '애니', 'gold four'),
#   ('top_lane', '아리', 'gold four'),
#   ('jungle', '카직스', 'gold three'),
#   ('No info', '트위치', 'silver two'),
#   '카밀',
#   '이블린',
#   '블리츠크랭크',
#   '야스오',
#   '하이머딩거',
#   ('adc', '카이사', 'gold three'),
#   ('mid_lane', '럼블', 'gold two'),
#   ('support', '레오나', 'silver one'),
#   ('jungle', '녹턴', 'silver two'),
#   ('mid_lane', '아트록스', 'silver one'),
#   '그레이브즈',
#   '다리우스',
#   '리산드라',
#   '이렐리아',
#   '소라카',
#   True],
#  [('support', '소라카', 'bronze four'),
#   ('adc', '루시안', 'bronze four'),
#   ('mid_lane', '니달리', 'bronze three'),
#   ('top_lane', '티모', 'bronze four'),
#   ('jungle', '엘리스', 'bronze three'),
#   '다리우스',
#   '야스오',
#   '베인',
#   '마스터 이',
#   '블리츠크랭크',
#   ('adc', '직스', 'bronze four'),
#   ('top_lane', '나르', 'bronze three'),
#   ('jungle', '이블린', 'bronze four'),
#   ('support', '제라스', 'bronze three'),
#   ('mid_lane', '아리', 'bronze two'),
#   '마스터 이',
#   '카밀',
#   '다리우스',
#   '제드',
#   '이즈리얼',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                      0                                1   \
# 0             (top_lane, 카르마, gold two)        (mid_lane, 애니, gold four)
# 1           (support, 소라카, bronze four)          (adc, 루시안, bronze four)
# 2           (mid_lane, 카사딘, bronze one)      (jungle, 아무무, bronze three)
# 3        (No info, 레오나, platinum three)          (No info, 렝가, gold two)
# 4          (jungle, 리 신, platinum four)         (adc, 애쉬, platinum four)
# 5            (jungle, 세주아니, bronze two)       (mid_lane, 제드, bronze one)
# 6               (adc, 이즈리얼, silver two)      (mid_lane, 아칼리, bronze one)
# 7          (top_lane, 올라프, silver four)        (adc, 이즈리얼, silver three)
# 8           (jungle, 리 신, bronze three)      (top_lane, 아칼리, bronze two)
# 9           (mid_lane, 야스오, gold three)        (top_lane, 제이스, gold one)
# 10         (jungle, 그라가스, silver three)     (support, 블리츠크랭크, iron four)
# 11          (mid_lane, 베이가, silver one)       (No info, 우르곳, gold three)
# ...
